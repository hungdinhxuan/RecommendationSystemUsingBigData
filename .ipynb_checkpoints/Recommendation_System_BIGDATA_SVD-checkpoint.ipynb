# %%
import joblib
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import numpy as np
from dask.distributed import Client
import vaex
client = Client()

# %%
movies = vaex.from_csv('../MovieLens/movie.csv')
ratings = vaex.from_csv('../MovieLens/rating.csv')

# %%
# !pip install git+https://github.com/gbolmier/funk-svd
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#   Cloning https://github.com/gbolmier/funk-svd to /tmp/pip-req-build-p22dp9wv
#   Running command git clone -q https://github.com/gbolmier/funk-svd /tmp/pip-req-build-p22dp9wv
# ...
#   Created wheel for funk-svd: filename=funk_svd-0.0.1.dev1-py3-none-any.whl size=9047 sha256=d333f0ee08f1a39150833ca627cc7f07c73d9c59c7e71df07b10bcc337dc182a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fws2a6s_/wheels/f8/93/18/db4114b3fafc2eb9a319db1e3b3c3465db51d1fdc1d4f2e769
# Successfully built funk-svd

# %%
import pandas as pd
from funk_svd import SVD

movies_df = movies.to_pandas_df()
rating_df = ratings.to_pandas_df()
# Out:
# distributed.worker - WARNING - Worker is at 113% memory usage. Pausing worker.  Process memory: 8.49 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.49 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Worker is at 111% memory usage. Pausing worker.  Process memory: 8.34 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.34 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Worker is at 113% memory usage. Pausing worker.  Process memory: 8.44 GiB -- Worker memory limit: 7.45 GiB
# ...

# %%
rating_df.columns = ['u_id', 'i_id', 'rating', 'timestamps']
movies_df.columns = ['i_id', 'title', 'genres']
rating_df
# Out:
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.78 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.78 GiB -- Worker memory limit: 7.45 GiB
# distributed.worker - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 8.78 GiB -- Worker memory limit: 7.45 GiB
#             u_id   i_id  rating           timestamps
# 0              1      2     3.5  2005-04-02 23:53:47
# ...
